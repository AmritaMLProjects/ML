# %%
import pandas as pd

# %%
df = pd.read_csv('EDA_census.csv')

# %%
df
# Out:
#      Table Name  State Code  District Code                          Area Name  \
# 0         C2308           0              0                              INDIA
# 1         C2308           0              0                              INDIA
# 2         C2308           0              0                              INDIA
# 3         C2308           0              0                              INDIA
# 4         C2308           0              0                              INDIA
# ...         ...         ...            ...                                ...
# 3127      C2308          35              0  State - ANDAMAN & NICOBAR ISLANDS
# 3128      C2308          35              0  State - ANDAMAN & NICOBAR ISLANDS
# 3129      C2308          35              0  State - ANDAMAN & NICOBAR ISLANDS
# 3130      C2308          35              0  State - ANDAMAN & NICOBAR ISLANDS
# 3131      C2308          35              0  State - ANDAMAN & NICOBAR ISLANDS
#
# ...

# %%
df_f = df[(df["Age-group"]=='20-24') & (df["Area Name"] == 'INDIA') & (df["Total/Rural/urban"]=='Total')]

# %%
df_f
# Out:
#    Table Name  State Code  District Code Area Name Total/Rural/urban  \
# 15      C2308           0              0     INDIA             Total
#
#    Age-group  Total Persons  Total Males  Total Females  \
# 15     20-24      111424222     57584693       53839529
#
#     Total Illiterate Persons  Total Illiterate Males  \
# 15                  18679492                 6467026
#
#     Total Illiterate Females  Total literate Persons  Total literate Males  \
# 15                  12212466                92744730              51117667
#
#     Total literate Females
# 15                41627063

# %%
(df_f['Total Illiterate Females']/df_f['Total Females'])*100
# Out:
# 15    22.683085
# dtype: float64

# %%
df_byagegroups = df[(df["Area Name"] == 'INDIA') & (df["Total/Rural/urban"]=='Total')]

# %%
df_byagegroups['litrecyrate'] = (df_byagegroups['Total literate Persons']/df_byagegroups['Total Persons'])*100
# Out:
# /var/folders/fj/4trbrrhn72b12j1r1vhm2g080000gn/T/ipykernel_9782/685460687.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_byagegroups['litrecyrate'] = (df_byagegroups['Total literate Persons']/df_byagegroups['Total Persons'])*100

# %%
import matplotlib.pyplot as plt
plt.scatter(df_byagegroups['Age-group'], df_byagegroups['litrecyrate'], alpha= 0.7, s = 50 )
plt.xticks(rotation=90)
plt.show()

# %%
df_bystate = df[~(df["Area Name"] == 'INDIA')]

# %%
df_bystate = df_bystate[(df_bystate["Age-group"]=='All ages') & (df["Total/Rural/urban"]=='Total')]
# Out:
# /var/folders/fj/4trbrrhn72b12j1r1vhm2g080000gn/T/ipykernel_9782/2786732625.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_bystate = df_bystate[(df_bystate["Age-group"]=='All ages') & (df["Total/Rural/urban"]=='Total')]

# %%
df_bystate.head(10)
# Out:
#     Table Name  State Code  District Code                 Area Name  \
# 87       C2308           1              0   State - JAMMU & KASHMIR
# 174      C2308           2              0  State - HIMACHAL PRADESH
# 261      C2308           3              0            State - PUNJAB
# 348      C2308           4              0        State - CHANDIGARH
# 435      C2308           5              0       State - UTTARAKHAND
# 522      C2308           6              0           State - HARYANA
# 609      C2308           7              0      State - NCT OF DELHI
# 696      C2308           8              0         State - RAJASTHAN
# 783      C2308           9              0     State - UTTAR PRADESH
# 870      C2308          10              0             State - BIHAR
#
#     Total/Rural/urban Age-group  Total Persons  Total Males  Total Females  \
# 87              Total  All ages       12541302      6640662        5900640
# ...

# %%
df_bystate['femalelitrecyrate'] = (df_bystate['Total literate Females']/df_bystate['Total Females'])*100

# %%
df_bystate.head(100)
# Out:
#      Table Name  State Code  District Code                          Area Name  \
# 87        C2308           1              0            State - JAMMU & KASHMIR
# 174       C2308           2              0           State - HIMACHAL PRADESH
# 261       C2308           3              0                     State - PUNJAB
# 348       C2308           4              0                 State - CHANDIGARH
# 435       C2308           5              0                State - UTTARAKHAND
# 522       C2308           6              0                    State - HARYANA
# 609       C2308           7              0               State - NCT OF DELHI
# 696       C2308           8              0                  State - RAJASTHAN
# 783       C2308           9              0              State - UTTAR PRADESH
# 870       C2308          10              0                      State - BIHAR
# 957       C2308          11              0                     State - SIKKIM
# ...

# %%
plt.scatter(df_bystate['Area Name'], df_bystate['femalelitrecyrate'], alpha= 0.7, s = 50 )
plt.xticks(rotation=90)
plt.show()

# %%
df_bystate['litrecyrate'] = (df_bystate['Total literate Persons']/df_bystate['Total Persons'])*100

# %%
plt.scatter(df_bystate['Area Name'], df_bystate['litrecyrate'], alpha= 0.7, s = 50 )
plt.xticks(rotation=90)
plt.show()
